# %% [markdown]
# <a href="https://colab.research.google.com/github/sankajithdjinasena/Data_Visualization_Practical/blob/main/Data_Visualization_2026_05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab: Data Visualization & Regression Mastery

# %% [markdown]
# ## 1. Environment Setup & Data Loading

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the tips dataset
tips_df = sns.load_dataset('tips')

# Display the first 5 rows of the DataFrame
display(tips_df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Visualization Tasks

# %%
# Task 1: The Baseline Regression
plt.figure(figsize=(8, 6))
sns.regplot(x='total_bill', y='tip', data=tips_df, line_kws={'color': 'red'}, color="blue")
plt.title('Total Bill vs. Tip (Baseline Regression)')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')
plt.show()

# %%
# Task 2: The Multi-Grid Slicer
sns.lmplot(x='total_bill', y='tip', col='time', data=tips_df, aspect=0.6, hue="smoker")
plt.suptitle('Total Bill vs. Tip by Time of Day and Smoking Status', y=1.02)
plt.show()

# %%
# Task 3: The All-in-One Pairplot
sns.pairplot(tips_df, hue='day', kind='reg')
plt.suptitle('Pairplot of Tipping Data by Day with Regression Lines', y=1.02)
plt.show()

# %% [markdown]
#  The relationship between `tip` and `total_bill` is clearly stronger than between `tip` and party `size`. The scatterplots and regression lines show a tighter, more linear trend for` tip` vs. `total_bill`, while `tip` vs. `size` is more spread out with a weaker slope. So, party size has a weaker relationship with the tip compared to the total bill.

# %%
# Task 4 : The Custom Dashboard
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

lunch_df = tips_df[tips_df['time'] == 'Lunch']
dinner_df = tips_df[tips_df['time'] == 'Dinner']

sns.regplot(x='total_bill', y='tip', data=lunch_df, ax=axes[0], line_kws={'color': 'green'})
axes[0].set_title('Total Bill vs. Tip for Lunch')
axes[0].set_xlabel('Total Bill ($)')
axes[0].set_ylabel('Tip ($)')

sns.regplot(x='total_bill', y='tip', data=dinner_df, ax=axes[1], line_kws={'color': 'blue'})
axes[1].set_title('Total Bill vs. Tip for Dinner')
axes[1].set_xlabel('Total Bill ($)')

plt.suptitle('Total Bill vs. Tip: Lunch vs. Dinner', y=1.05)
plt.tight_layout()
plt.show()
